# %% [markdown]
# <a href="https://colab.research.google.com/github/AyaAbdElNaem/AI_Tools/blob/main/Dr_Ibrahim_Bassuoni_Aya_AbdelNaem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aya AbdelNaem Mahmoud

# %% [markdown]
# #Drive Link
# **https://drive.google.com/drive/folders/17OPdo0aLTzI33tqjcJZ78aPfUSyKO0r5?usp=drive_link**
# ** **

# %% [markdown]
# # Portfolio Link
# **https://story-display-box.lovable.app/**
# ** **

# %% [markdown]
# # PetNutri Link
#
# **https://rag-six-rouge.vercel.app/**
