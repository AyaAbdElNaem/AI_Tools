# %% [markdown]
# <a href="https://colab.research.google.com/github/AyaAbdElNeam/AI_Tools/blob/main/Lab3_Practice_Lab_Image_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practice Lab: Image Processing & Classical CV
#
#
# **Grading:** Complete all exercises and answer all thinking questions. Your submitted notebook should run top-to-bottom without errors.
#
# ---

# %% [markdown]
# ## Section 1: Setup

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage import data
import time

# %% [markdown]
# ---
# # Part A: Image Fundamentals
#
# We will work with the **`coffee`** image (a color photo of a coffee cup) and the **`chelsea`** image (a photo of a cat). Both come from `skimage.data`.
#
# ---

# %% [markdown]
# ## Exercise A1: Load, Inspect, and Display
#
# **Task:** Load the `coffee` image from `skimage.data`, print its shape, data type, then display it.

# %%
# TODO: Load the coffee image
image = ___

# TODO: Print shape, dtype, min value, max value
print("Shape:", ___)
print("Data type:", ___)

# TODO: Display the image with a title
plt.figure(figsize=(8, 5))
___
___
plt.axis('off')
plt.show()

# %% [markdown]
# ## Exercise A2: Grayscale Conversion and Shape Comparison
#
# **Task:**
# 1. Convert the coffee image to grayscale.
# 2. Print the shape of both the color and grayscale versions.
# 3. Display them side by side in a single figure with 1 row and 2 columns.
#
# **Remember:** Use `cv2.cvtColor()` with the correct color code for RGB → Gray.

# %%
# TODO: Convert to grayscale
gray = ___

# TODO: Print both shapes
print("Color shape:", ___)
print("Grayscale shape:", ___)

# TODO: Display side by side (1 row, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].imshow(___)
axes[0].set_title("Color (RGB)")
axes[0].axis('off')

axes[1].imshow(___, cmap='gray')
axes[1].set_title("Grayscale")
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise A3: Crop and Resize
#
# **Task:**
# 1. Crop the **center 200×200 region** from the grayscale coffee image.
# 2. Resize the grayscale image to **100×150** (width × height).
# 3. Display the original grayscale, the crop, and the resized image in a single row.
#
# **Hint:** For center cropping, you need to calculate the start row/column from the center of the image.

# %%
height, width = gray.shape

# TODO: Calculate center crop coordinates for a 200x200 region
center_y, center_x = ___, ___
start_y = ___
start_x = ___

# TODO: Crop
cropped = gray[___:___, ___:___]

# TODO: Resize the full grayscale image to width=150, height=100
resized = cv2.resize(___, (___,  ___))

# Print shapes to verify
print("Original:", gray.shape)
print("Cropped:", cropped.shape)
print("Resized:", resized.shape)

# Display all three
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

axes[0].imshow(gray, cmap='gray')
axes[0].set_title(f"Original {gray.shape[1]}×{gray.shape[0]}")
axes[0].axis('off')

axes[1].imshow(cropped, cmap='gray')
axes[1].set_title(f"Center Crop {cropped.shape[1]}×{cropped.shape[0]}")
axes[1].axis('off')

axes[2].imshow(resized, cmap='gray')
axes[2].set_title(f"Resized {resized.shape[1]}×{resized.shape[0]}")
axes[2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise A4: Brightness Adjustment + Histograms
#
# **Task:**
# 1. Create a **brighter** version (add 70) and a **darker** version (subtract 70) of the grayscale coffee image.
# 2. Display all three images in the top row and their histograms in the bottom row (2 rows × 3 columns).
#
# **Remember:** You must handle overflow/underflow with `np.clip` and type casting.

# %%
# TODO: Create brighter image (add 70, handle overflow)
brighter = ___

# TODO: Create darker image (subtract 70, handle underflow)
darker = ___

# Display: 2 rows × 3 columns (images on top, histograms on bottom)
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

titles = ['Darker (−70)', 'Original', 'Brighter (+70)']
imgs = [darker, gray, brighter]

for i in range(3):
    # Top row: images
    axes[0, i].imshow(imgs[i], cmap='gray', vmin=0, vmax=255)
    axes[0, i].set_title(titles[i], fontsize=13)
    axes[0, i].axis('off')

    # TODO: Bottom row: histograms (use .ravel(), 256 bins, range 0-255)
    axes[1, i].hist(___, bins=___, range=(0,255), color='steelblue', edgecolor='none')
    axes[1, i].set_title(f"Histogram — {titles[i]}", fontsize=11)
    axes[1, i].set_xlim(0, 255)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise A5: Color Detection on the Cat (Chelsea)
#
# **Task:** Use the `chelsea` image (a cat) and detect **orange/ginger fur** using HSV color masking.
#
# Steps:
# 1. Load the `chelsea` image.
# 2. Convert it from RGB to HSV.
# 3. Define a lower and upper HSV bound that captures orange/ginger tones. Start with approximately: H=[150,170], S=[0, 255], V=[0, 255] — then adjust.
# 4. Create a mask and apply it to the original image.
# 5. Display the original, the mask, and the masked result in a row.

# %%
# TODO: Load the chelsea (cat) image
cat = ___

# TODO: Convert to HSV
cat_hsv = ___

# TODO: Define lower and upper bounds for orange/ginger fur
lower_orange = np.array([___,___,___])
upper_orange = np.array([___,___,___])

# TODO: Create the mask using cv2.inRange()
mask = ___

# TODO: Apply mask to original image using cv2.bitwise_and()
result = cv2.bitwise_and(cat, ___, mask=___)

# Display
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].imshow(cat)
axes[0].set_title("Original (Chelsea)")
axes[0].axis('off')

axes[1].imshow(mask, cmap='gray')
axes[1].set_title("Orange Mask")
axes[1].axis('off')

axes[2].imshow(result)
axes[2].set_title("Masked Result")
axes[2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise A6: Histogram Equalization
#
# **Task:**
# 1. Apply histogram equalization to the grayscale coffee image.
# 2. Display the original and equalized images with their histograms (2×2 grid).
#
# **Which function?** `cv2.equalizeHist()`

# %%
# TODO: Apply histogram equalization
equalized = ___

# Display 2×2: images on left, histograms on right
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

axes[0, 0].imshow(gray, cmap='gray')
axes[0, 0].set_title("Original Grayscale")
axes[0, 0].axis('off')

# TODO: Plot original histogram
axes[0, 1].hist(___, bins=256, range=(0, 255), color='gray', edgecolor='none')
axes[0, 1].set_title("Original Histogram")

axes[1, 0].imshow(equalized, cmap='gray')
axes[1, 0].set_title("After Equalization")
axes[1, 0].axis('off')

# TODO: Plot equalized histogram
axes[1, 1].hist(___, bins=256, range=(0, 255), color='teal', edgecolor='none')
axes[1, 1].set_title("Equalized Histogram")

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# # Part B: Filters, Edge Detection & Corner Detection
#
# For this section, we use the **`camera`** image (a classic 512×512 grayscale photo of a cameraman) and the **`coins`** image.
#
# ---

# %% [markdown]
# ## Exercise B1: Apply and Compare Blur Filters
#
# **Task:** Apply four blur filters to the `camera` image and display all five (original + 4 filters) in a single row.
#
# Use these settings:
# - Average blur: 7×7
# - Gaussian blur: 7×7, sigma=0
# - Median blur: 7
# - Bilateral filter: d=7, sigmaColor=75, sigmaSpace=75

# %%
# Load the camera image (already grayscale)
cam = data.camera()

# TODO: Apply the four blur filters
avg_blur = ___
gauss_blur = ___
median_blur = ___
bilateral_blur = ___

# Display all 5 in a row
fig, axes = plt.subplots(1, 5, figsize=(25, 5))
titles = ['Original', 'Average 7×7', 'Gaussian 7×7', 'Median 7', 'Bilateral d=7']
images = [cam, avg_blur, gauss_blur, median_blur, bilateral_blur]

for ax, img, title in zip(axes, images, titles):
    ax.imshow(img, cmap='gray')
    ax.set_title(title, fontsize=12)
    ax.axis('off')

plt.suptitle("Blur Filter Comparison", fontsize=15, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise B2: Salt-and-Pepper Noise — Which Filter Wins?
#
# **Task:**
# 1. Add salt-and-pepper noise to the camera image (5% corruption).
# 2. Apply Gaussian blur (7×7) and Median blur (7) to the noisy image.
# 3. Display: noisy image, Gaussian result, Median result — in one row.
#
# The noise function is provided for you.

# %%
def add_salt_pepper_noise(image, amount=0.05):
    """Add salt-and-pepper noise to an image."""
    noisy = image.copy()
    total = image.size
    # Salt (white pixels)
    num_salt = int(total * amount / 2)
    salt_rows = np.random.randint(0, image.shape[0], num_salt)
    salt_cols = np.random.randint(0, image.shape[1], num_salt)
    noisy[salt_rows, salt_cols] = 255
    # Pepper (black pixels)
    num_pepper = int(total * amount / 2)
    pepper_rows = np.random.randint(0, image.shape[0], num_pepper)
    pepper_cols = np.random.randint(0, image.shape[1], num_pepper)
    noisy[pepper_rows, pepper_cols] = 0
    return noisy

np.random.seed(42)
noisy_cam = add_salt_pepper_noise(cam, amount=0.05)

# TODO: Apply Gaussian blur (7×7) to the NOISY image
gauss_denoised = ___

# TODO: Apply Median blur (7) to the NOISY image
median_denoised = ___

# Display
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
titles = ['Noisy (5% S&P)', 'Gaussian 7×7', 'Median 7']
images = [noisy_cam, gauss_denoised, median_denoised]

for ax, img, title in zip(axes, images, titles):
    ax.imshow(img, cmap='gray')
    ax.set_title(title, fontsize=13)
    ax.axis('off')

plt.suptitle("Denoising Salt-and-Pepper: Gaussian vs Median", fontsize=15, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Think About It — B2
#
# 1. Which filter did a better job removing the salt-and-pepper noise? Why?

# %% [markdown]
# **Your answer:**
#
# *(Double-click this cell and type your answer here)*

# %% [markdown]
# ## Exercise B3: Edge Detection Trio
#
# **Task:** Apply Sobel, Laplacian, and Canny edge detection to the `camera` image and display all four (original + 3 edge maps) in a row.
#
# **Steps:**
# 1. First, apply a small Gaussian blur (3×3) to reduce noise.
# 2. Compute Sobel X, Sobel Y, and combine them into magnitude.
# 3. Compute Laplacian (take absolute value, convert to uint8).
# 4. Compute Canny with thresholds (50, 150).

# %%
# Step 1: Pre-blur
blurred_cam = cv2.GaussianBlur(cam, (3, 3), 0)

# TODO Step 2: Sobel
sobel_x = cv2.Sobel(___, cv2.CV_64F, dx=___, dy=___, ksize=3)
sobel_y = cv2.Sobel(___, cv2.CV_64F, dx=___, dy=___, ksize=3)
sobel_mag = np.sqrt(___**2 + ___**2)
sobel_mag = np.uint8(np.clip(sobel_mag, 0, 255))

# TODO Step 3: Laplacian
laplacian = cv2.Laplacian(___, cv2.CV_64F)
laplacian_abs = np.uint8(np.absolute(___))

# TODO Step 4: Canny
canny = cv2.Canny(___, ___, ___)

# Display
fig, axes = plt.subplots(1, 4, figsize=(22, 5))
titles = ['Original', 'Sobel (Combined)', 'Laplacian', 'Canny (50, 150)']
images = [cam, sobel_mag, laplacian_abs, canny]

for ax, img, title in zip(axes, images, titles):
    ax.imshow(img, cmap='gray')
    ax.set_title(title, fontsize=13)
    ax.axis('off')

plt.suptitle("Edge Detection Methods Compared", fontsize=15, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise B4: Canny Threshold Exploration
#
# **Task:** Apply Canny edge detection with three different threshold pairs to the camera image and display them.
#
# Use: (30, 80), (50, 150), and (120, 250).
#
# **No hints this time** — write the full code yourself.

# %%
# TODO: Apply three Canny edge detections with different thresholds
# and display them in a 1×4 grid (original + 3 Canny results)
# Label each with its threshold values.

# %% [markdown]
# ### Think About It — B4
#
# 1. As you increase the thresholds, do you get **more** or **fewer** edges? Why?
# 2. Which threshold pair gives the cleanest result for the cameraman image — one that captures the important outlines without too much clutter?

# %% [markdown]
# **Your answer:**
#
# *(Double-click this cell and type your answer here)*

# %% [markdown]
# ## Exercise B5: Corner Detection on Coins
#
# **Task:** Use the `coins` image to detect corners using both **Harris** and **Shi-Tomasi**, then display them side by side.
#
# Steps:
# 1. Load the `coins` image (it's already grayscale).
# 2. Apply Harris corner detection and mark the top corners in red on a color copy.
# 3. Apply Shi-Tomasi (`goodFeaturesToTrack`) to find the best 80 corners and mark them in green on another color copy.
# 4. Display both results side by side.

# %%
# Load coins image
coins = data.coins()
print("Coins shape:", coins.shape)

# === Harris ===
# TODO: Apply Harris corner detection
harris_response = cv2.cornerHarris(
    coins.astype(np.float32),
    blockSize=___,
    ksize=___,
    k=___
)
harris_response = cv2.dilate(harris_response, None)

# Mark corners on a color copy (convert grayscale to BGR for colored marks)
harris_display = cv2.cvtColor(coins, cv2.COLOR_GRAY2RGB)
# Threshold: keep only the strongest corners (top 1% of response)
threshold = ___ * harris_response.max()
harris_display[harris_response > threshold] = [255, 0, 0]  # Red

# === Shi-Tomasi ===
# TODO: Detect the best 80 corners using Shi-Tomasi
corners_st = cv2.goodFeaturesToTrack(
    coins,
    maxCorners=___,
    qualityLevel=___,
    minDistance=___
)

shi_display = cv2.cvtColor(coins, cv2.COLOR_GRAY2RGB)
if corners_st is not None:
    for corner in np.int32(corners_st):
        x, y = corner.ravel()
        cv2.circle(shi_display, (x, y), 4, (0, 255, 0), -1)

# Display side by side
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

axes[0].imshow(harris_display)
axes[0].set_title("Harris Corners (Red)", fontsize=13)
axes[0].axis('off')

axes[1].imshow(shi_display)
axes[1].set_title(f"Shi-Tomasi — {len(corners_st)} Corners (Green)", fontsize=13)
axes[1].axis('off')

plt.suptitle("Corner Detection on Coins", fontsize=15, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Think About It — B5
#
# 1. Where do the detected corners cluster — on the coin **edges**, on the **text/details** on the coins, or on the **background**? Why?
# 2. If you wanted to count the number of coins in the image, would corner detection alone be a good approach? Why or why not?

# %% [markdown]
# **Your answer:**
#
# *(Double-click this cell and type your answer here)*

# %% [markdown]
# ---
# # Part C: Mini Challenge — Full Pipeline
#
# This is your integration exercise. You will build a **complete pipeline** from raw image to ML features using the `moon` image.
#
# ---

# %% [markdown]
# ## Challenge: Moon Surface Analysis Pipeline
#
# The `moon` image is a grayscale photo of the moon's surface. Your job:
#
# 1. **Load** the moon image and display it.
# 2. **Equalize** its histogram (the moon image has poor contrast).
# 3. **Apply a bilateral filter** to smooth while preserving craters (edges).
# 4. **Detect edges** using Canny on the filtered image — experiment with thresholds to capture crater rims.
# 5. **Detect corners** using Shi-Tomasi on the filtered image — these should catch crater rim intersections.
# 6. **Final display:** Create a 2×3 figure showing:
#    - Row 1: Original, Equalized, Bilateral-filtered
#    - Row 2: Canny edges, Shi-Tomasi corners (on color copy), Overlay of edges + corners on the original
#
# Write the entire pipeline yourself.

# %%
# ============================================
# YOUR FULL PIPELINE HERE
# ============================================

# Step 1: Load the moon image


# Step 2: Histogram equalization


# Step 3: Bilateral filter on the equalized image


# Step 4: Canny edge detection on the filtered image


# Step 5: Shi-Tomasi corner detection on the filtered image


# Step 6: Create the 2×3 display
# Row 1: Original | Equalized | Bilateral
# Row 2: Canny edges | Corners marked | Overlay

# %% [markdown]
# Challenge
#
# Answer the following:
#
# 1. Why did we equalize the histogram **before** filtering and edge detection? What would happen if we skipped that step?
# 2. Why is the bilateral filter a better choice than Gaussian for this image? What would Gaussian blur do to the crater edges?
# 3. Look at your Canny output: did it capture most crater rims? If not, what threshold adjustments would help?

# %% [markdown]
# **Your answer:**
#
# *(Double-click this cell and type your answer here)*
